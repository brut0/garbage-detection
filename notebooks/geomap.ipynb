# %%
import numpy as np
import pandas as pd
import re
import folium # map rendering library
from folium.plugins import HeatMap
from geopy.geocoders import Nominatim

# %%
df = pd.read_csv('lat-lon.csv')

# %%
geolocator = Nominatim(user_agent="ny_explorer")
address = 'Татарстан'
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(address, latitude, longitude))

tmap = folium.Map(location=[latitude, longitude], zoom_start=8)

for i in range(len(df)):
    folium.Circle(
        radius=30,
        location=[df.Latitude[i], df.Longitude[i]],
        popup=df['Адрес установки камеры'][i],
        color='crimson',
        fill=True,
    ).add_to(tmap)

#HeatMap(df[['Latitude', 'Longitude']], radius=10, blur=10).add_to(kmap)
    
tmap
# Out:
# The geograpical coordinate of Татарстан are 55.448217, 50.4763591.
# ...

# %%
geolocator = Nominatim(user_agent="ny_explorer")
address = 'Казань'
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(address, latitude, longitude))

kmap = folium.Map(location=[latitude, longitude], zoom_start=10)

kgeo = r'./kazan.geojson'

choropleth = folium.Choropleth(
    geo_data=kgeo,
    #data=df,
    #columns=['Name'],
    #key_on='properties.district',
    fill_color='YlGnBu', 
    fill_opacity=0.3, 
    line_opacity=0.6,
    highlight=True,
    legend_name='Kazan districts'
)

choropleth.add_to(kmap)
    
kmap
# Out:
# The geograpical coordinate of Казань are 55.7823547, 49.1242266.
# ...

# %%
geolocator = Nominatim(user_agent="ny_explorer")
address = 'Казань'
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(address, latitude, longitude))

kmap = folium.Map(location=[latitude, longitude], zoom_start=10)

kgeo = r'./kazan.geojson'

choropleth = folium.Choropleth(
    geo_data=kgeo,
    #data=df,
    #columns=['Name'],
    #key_on='properties.district',
    fill_color='YlGnBu', 
    fill_opacity=0.1, 
    line_opacity=0.5,
    highlight=True,
    legend_name='Kazan districts'
)

choropleth.add_to(kmap)

HeatMap(df[['Latitude', 'Longitude']], radius=20, blur=10).add_to(kmap)
    
kmap
# Out:
# The geograpical coordinate of Казань are 55.7823547, 49.1242266.
# ...

# %%
kmap.save("kmap.html")
